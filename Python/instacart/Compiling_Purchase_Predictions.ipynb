# %%
import pandas as pd
import numpy as np

# %%
prediction = pd.read_csv("c:/users/hello/desktop/cluster3predictions.csv")

# %%
prediction.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0           0             0   1735923       19     test            10
# 1           1             1   2088686      221     test            24
# 2           2             2   2088686      221     test            24
# 3           3             3   2088686      221     test            24
# 4           4             4   2088686      221     test            24
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  aisle_id  \
# 0          6                 17                       8        9387        24
# 1          1                 21                      15        9387        24
# 2          1                 21                      15        9387        24
# 3          1                 21                      15        9387        24
# 4          1                 21                      15        9387        24
#
#    Unnamed: 0.1.1  User Id  cluster  percent_product  Percent_aisle  \
# ...

# %%
prediction = prediction[['user_id','product_id','reorder_prediction']]

# %%
prediction = prediction.drop_duplicates()

# %%
prediction = prediction[prediction['reorder_prediction'] == 1]

# %%
prediction.head()
# Out:
#     user_id  product_id  reorder_prediction
# 0        19        9387                   1
# 7       535        9387                   1
# 8       896        9387                   1
# 18      995        9387                   1
# 20     1285        9387                   1

# %%
prediction = prediction.groupby('user_id')['product_id'].apply(lambda x: np.unique(np.hstack(x)))

# %%
k = pd.DataFrame(prediction)

# %%
k.to_csv("c:/users/hello/desktop/cluster3_predictions.csv")
